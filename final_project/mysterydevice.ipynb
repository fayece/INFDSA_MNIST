# %% [markdown]
# # Implementatie van het eindprogramma voor de Mystery Device

# %%
from read_image import load_image, classify_image, DrawingApp

input_nodes = 28 * 28
output_nodes = 10
total_models = 12

hidden_layer_sizes = [[110 + (i * 3)] for i in range(total_models)]

# %% [markdown]
# ### Testen van verschillende plaatjes

# %%
from pathlib import Path

# Scans both ./ and ./images/, from the final_project directory, to support both sorted and unsorted image storage
png_files = sorted(Path(".").glob("*.png")) + sorted(Path(".").glob("images/*.png"))

header = f"{'Bestandsnaam':<13} | {'Verwacht':<12} | {'Voorspelling':<12} | {'Conf. #1':<8} | {'Gok (bij niet herkend)':<22} | {'Runner-up (#2)':<14}"
print(header)
print("-" * len(header))

for png_file in png_files:
    filename = png_file.name

    name_without_extension = png_file.stem
    if name_without_extension.isdigit():
        expected = name_without_extension
    else:
        expected = "niet herkend"

    image = load_image(png_file)
    pred, conf1, guess, second_digit, conf2 = classify_image(image)

    if pred == "niet herkend":
        guess_str = guess
    else:
        guess_str = "-"

    runner_up_str = f"{second_digit} ({conf2:.2%})"

    print(
        f"{filename:<13} | {expected:<12} | {pred:<12} | {conf1:<8.2%} | {guess_str:<22} | {runner_up_str:<15}"
    )
# Out:
# Bestandsnaam  | Verwacht     | Voorspelling | Conf. #1 | Gok (bij niet herkend) | Runner-up (#2)
# ------------------------------------------------------------------------------------------------
# 0.png         | 0            | 0            | 99.99%   | -                      | 9 (0.01%)
# 1.png         | 1            | 1            | 99.81%   | -                      | 8 (0.13%)
# 2.png         | 2            | 2            | 98.43%   | -                      | 3 (1.35%)
# 3.png         | 3            | 3            | 99.98%   | -                      | 5 (0.02%)
# 4.png         | 4            | 4            | 99.69%   | -                      | 7 (0.25%)
# 5.png         | 5            | 5            | 96.90%   | -                      | 3 (3.10%)
# 6.png         | 6            | 6            | 97.94%   | -                      | 8 (1.57%)
# 7.png         | 7            | 7            | 97.11%   | -                      | 2 (2.71%)
# ...

# %% [markdown]
# ### Zelf een plaatje tekenen en testen

# %% [markdown]
# > Goed om te weten: Dit subproces is gemaakt met behulp van AI. Gezien de werking van deze functionaliteit niet onderdeel uitmaakt van de opdracht, is dit vooral neergezet als proof of concept, en om de presentatie leuker en interactiever te maken.

# %%
import subprocess, sys

subprocess.run([sys.executable, "read_image.py"])
# Out:
# CompletedProcess(args=['/Users/faye/miniconda3/envs/infdsa_mnist/bin/python', 'read_image.py'], returncode=0)
